# %% [markdown]
# <a href="https://colab.research.google.com/github/tahsinadia/Practice-on-Collab/blob/main/Copy_of_Copy_of_Module_7_try_catch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = y

try:
  x=y
except ZeroDivisionError :
  print("you cant divide a number by 0")
except Exception as e:
  print(e)
print("hello world")


# Output will be : Name Y is not defined  , hello world
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2025176405.py in <cell line: 0>()
# ----> 1 x = y
#       2
#       3 try:
#       4   x=y
#       5 except ZeroDivisionError :
#
# NameError: name 'y' is not defined

# %%
from os import replace
from functools import reduce

with open("./sample_data/sample.txt", "r") as file:
    string_list = file.readlines()

    # total lines koyta
    total_lines = len(string_list)

    # word ber korbo
    number_of_words = list(map(lambda x: len(x.split()), string_list))

    print(number_of_words)
    total_number_of_words = reduce(lambda x, y: x + y, number_of_words)
    print(total_number_of_words)

    # 1. new line delete
    string_list = list(map(str.strip, string_list))  # Convert to list

    # 2.  space delete

    string_list = list(map(lambda x : x.replace(" "," "),string_list))

    # koita character

    number_of_character = list(map(lambda x : len(x),string_list))
    #total character
    total_number_of_characters = reduce(lambda x,y : x+y , number_of_character)


    with open("./sample_data/","counter_of_string.txt","w") as file:
     file.write(f"total line:{total_lines}\n total  number of words: {total_number_of_words}\n total number of char: {total_number_of_characters}")
# Out:
# []
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1817461054.py in <cell line: 0>()
#      12
#      13     print(number_of_words)
# ---> 14     total_number_of_words = reduce(lambda x, y: x + y, number_of_words)
#      15     print(total_number_of_words)
#      16
#
# TypeError: reduce() of empty iterable with no initial value

# %%
from functools import reduce

with open("./sample_data/sample.txt", "r") as file:
    string_list = file.readlines()

    # total lines koyta
    total_lines = len(string_list)

    # word ber korbo
    number_of_words = list(map(lambda x: len(x.split()), string_list))

    print(number_of_words)
    total_number_of_words = reduce(lambda x, y: x + y, number_of_words)
    print(total_number_of_words)

    # 1. new line delete
    string_list = list(map(str.strip, string_list))

    # 2. space delete
    string_list = list(map(lambda x: x.replace(" ", ""), string_list))

    # koita character
    number_of_character = list(map(lambda x: len(x), string_list))

    # total character
    total_number_of_characters = reduce(lambda x, y: x + y, number_of_character)

    # Write to file
    with open("./sample_data/counter_of_string.txt", "w") as file:
        file.write(f"total line: {total_lines}\n total number of words: {total_number_of_words}\n total number of char: {total_number_of_characters}")from functools import reduce

with open("./sample_data/sample.txt", "r") as file:
    string_list = file.readlines()

    # total lines koyta
    total_lines = len(string_list)

    # word ber korbo
    number_of_words = list(map(lambda x: len(x.split()), string_list))

    print(number_of_words)
    total_number_of_words = reduce(lambda x, y: x + y, number_of_words)
    print(total_number_of_words)

    # 1. new line delete
    string_list = list(map(str.strip, string_list))

    # 2. space delete
    string_list = list(map(lambda x: x.replace(" ", ""), string_list))

    # koita character
    number_of_character = list(map(lambda x: len(x), string_list))

    # total character
    total_number_of_characters = reduce(lambda x, y: x + y, number_of_character)

    # Write to file
    with open("./sample_data/counter_of_string.txt", "w") as file:
        file.write(f"total line: {total_lines}\n total number of words: {total_number_of_words}\n total number of char: {total_number_of_characters}")

# %%
with open("./sample_data/sample.txt","r")as file:
  strings = file.readlines()

  total_lines = len(strings)
  # total line koita
  print(total_lines)

# %%
file = open("./sample_data/sample.txt","r")

content = file.read()

print(type(content))

file.close()

print(file.closed) ## When we open a file after work is done, we must close the file otherwise  data ca be liakage or any problem can be occured.

# %%
file = open("./sample_data/sample.txt","r")

content = file.read()

print(content)

# %%
file = open("./sample_data/sample.txt","r")

content = file.readlines()

print(content)

# %%
file = open("./sample_data/sample.txt","r")

content = file.read()

print(type(content))

# %%
with open("./sample_data/sample.txt","r") as file:

  content = file.readlines()
  print(content)

print(file.closed)
# Out:
# []
# True

# %%
with open("./sample_data/sample.txt","r") as file:
  for line in file:
    print(line,end="")

# %%
with open("./sample_data/sample.txt","r") as file:
  for line in file:
    l = line.strip() #new line will be delete
    print(line)

# %%
file = open("./sample_data/sample.txt","r")



content = file.read()

print(type(content))

print(file.closed) ## When we open a file after work is done, we must close the file otherwise  data ca be liakage or any problem can be occured.

file.close
# Out:
# <class 'str'>
# False
# <function TextIOWrapper.close()>

# %%
file = open("./sample_data/sample.txt","r")

content = file.readlines()

content = list(map(str.strip,content))



filter_content = list(filter(lambda x : len(x)>=1,content))

print(filter_content)
# Out:
# []

# %% [markdown]
# File Write

# %%
# creating new file and writing there
with open("./sample_data/test.txt","w")as  file :

  file.write("Hello test file\n")
  file.write("What is learning going on ?")

# %%
# writing on a existing file
# It overwrites the file
with open("./sample_data/test.txt","w")as  file :

  file.write("Second Attempt\n")
  file.write("lerning is going on fast\n ?")

# %%
# No Overwritiing just append the text later
# append mode
with open("./sample_data/test.txt","a")as  file :

  file.write("The lerning of AI/ML is fun\n")
  file.write("I am enjoying the classes ?")

# %%
strings = ['hello', 'hi', 'good bye','whats up!']

# %%
string = ['hello','hi','good-bye','whats-up']

with open("./sample_data/test2.txt","a")as  file :

  file.writelines(string)

# %% [markdown]
# File Pointer

# %%
with open("./sample_data/test2.txt", "r") as file:  # ✅ "r" = read mode
    print(file.tell())  # Current cursor position
    print(file.read())   # Read the content
    print(file.tell())   # Cursor after reading
# Out:
# 0
# hellohigood-byewhats-uphellohigood-byewhats-uphellohigood-byewhats-uphellohigood-byewhats-uphellohigood-byewhats-up
# 115

# %%
with open("./sample_data/sample.txt", "r") as file:  # ✅ "r" = read mode
    print(file.tell())  # Current cursor position
    print(file.read())   # Read the content
    print(file.tell())   # Cursor after reading
    print(file.read()) # last index theke pora shuru korsi
# Out:
# 0
#
# 0

# %%
with open("./sample_data/sample.txt", "r") as file:  # ✅ "r" = read mode
    print(file.tell())  # Current cursor position
    print(file.read(5))
    print(file.tell())

    print(file.read())
    print(file.tell())
# Out:
# 0
#
# 0
#
# 0

# %%
with open("./sample_data/sample.txt", "r") as file:  # ✅ "r" = read mode
    print(file.tell())  # Current cursor position

    file.seek(5)
    print(file.tell())
# Out:
# 0
# 5

# %%
with open("./sample_data/sample.txt", "r") as file:  # ✅ "r" = read mode
    print(file.tell())  # Current cursor position

    print(file.read(5))

    print(file.tell())

    file.seek(0)
    print(file.tell())
    print(file.read(5))
# Out:
# 0
#
# 0
# 0

# %% [markdown]
# Get the text from sample.txt, and count the following
#
# number of lines
#
# number of words
#
# number of characters
#
# and save it to the
# counter_of_string.txt file

# %%
with open("./sample_data/sample.txt","r")as file:
  strings = file.read()

  print(strings)

# %%
with open("./sample_data/sample.txt","r")as file:
  strings = file.readlines()## read kore line by line and then akta akta kore list ae rakhe dae


  print(strings)
# Out:
# []

# %%
with open("./sample_data/sample.txt","r")as file:
  strings = file.readlines()

  total_lines = len(strings)
  # total line koita
  print(total_lines)
# Out:
# 0

# %%
with open("./sample_data/sample.txt","r")as file:
  strings = file.readlines()

  # total lines koyta
  total_lines = len(strings)

  # word ber korbo

  number_of_words = list(map(lambda x : len (x.split()), strings))



  print(number_of_words)
# Out:
# []

# %%
from functools import reduce

with open("./sample_data/sample.txt","r")as file:
  strings = file.readlines()

  # total lines koyta
  total_lines = len(strings)

  # word ber korbo

  number_of_words = list(map(lambda x : len (x.split()), strings))

  print(number_of_words)
  total_number_of_words = reduce(lambda x , y : x+ y ,number_of_words)
  print(total_number_of_words)


  print(strings)
# Out:
# []
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-350904369.py in <cell line: 0>()
#      12
#      13   print(number_of_words)
# ---> 14   total_number_of_words = reduce(lambda x , y : x+ y ,number_of_words)
#      15   print(total_number_of_words)
#      16
#
# TypeError: reduce() of empty iterable with no initial value

# %%
from functools import reduce

with open("./sample_data/sample.txt", "r") as file:
    string_list = file.readlines()

    # total lines koyta
    total_lines = len(string_list)

    # word ber korbo
    number_of_words = list(map(lambda x: len(x.split()), string_list))

    print(number_of_words)
    total_number_of_words = reduce(lambda x, y: x + y, number_of_words)
    print(total_number_of_words)

    string_list = list(map(str.strip, string_list))  # Convert to list
    print(string_list)

# %%
from os import replace
from functools import reduce

with open("./sample_data/sample.txt", "r") as file:
    string_list = file.readlines()

    # total lines koyta
    total_lines = len(string_list)

    # word ber korbo
    number_of_words = list(map(lambda x: len(x.split()), string_list))

    print(number_of_words)
    total_number_of_words = reduce(lambda x, y: x + y, number_of_words)
    print(total_number_of_words)

    # 1. new line delete
    string_list = list(map(str.strip, string_list))  # Convert to list

    # 2.  space delete

    string_list = list(map(lambda x : x.replace(" "," "),string_list))
    print(string_list)

# %%
from os import replace
from functools import reduce

with open("./sample_data/sample.txt", "r") as file:
    string_list = file.readlines()

    # total lines koyta
    total_lines = len(string_list)

    # word ber korbo
    number_of_words = list(map(lambda x: len(x.split()), string_list))

    print(number_of_words)
    total_number_of_words = reduce(lambda x, y: x + y, number_of_words)
    print(total_number_of_words)

    # 1. new line delete
    string_list = list(map(str.strip, string_list))  # Convert to list

    # 2.  space delete

    string_list = list(map(lambda x : x.replace(" "," "),string_list))

    # koita character ase

    number_of_character =
    print(string_list)

# %%
from os import replace
from functools import reduce

with open("./sample_data/sample.txt", "r") as file:
    string_list = file.readlines()

    # total lines koyta
    total_lines = len(string_list)

    # word ber korbo
    number_of_words = list(map(lambda x: len(x.split()), string_list))

    print(number_of_words)
    total_number_of_words = reduce(lambda x, y: x + y, number_of_words)
    print(total_number_of_words)

    # 1. new line delete
    string_list = list(map(str.strip, string_list))  # Convert to list

    # 2.  space delete

    string_list = list(map(lambda x : x.replace(" "," "),string_list))
    print(string_list)

# %%
from os import replace
from functools import reduce

with open("./sample_data/sample.txt", "r") as file:
    string_list = file.readlines()

    # total lines koyta
    total_lines = len(string_list)

    # word ber korbo
    number_of_words = list(map(lambda x: len(x.split()), string_list))

    print(number_of_words)
    total_number_of_words = reduce(lambda x, y: x + y, number_of_words)
    print(total_number_of_words)

    # 1. new line delete
    string_list = list(map(str.strip, string_list))  # Convert to list

    # 2.  space delete

    string_list = list(map(lambda x : x.replace(" "," "),string_list))

    # koita character

    number_of_character = list(map(lambda x : len(x),string_list))
    print(number_of_character)

# %%
from os import replace
from functools import reduce

with open("./sample_data/sample.txt", "r") as file:
    string_list = file.readlines()

    # total lines koyta
    total_lines = len(string_list)

    # word ber korbo
    number_of_words = list(map(lambda x: len(x.split()), string_list))

    print(number_of_words)
    total_number_of_words = reduce(lambda x, y: x + y, number_of_words)
    print(total_number_of_words)

    # 1. new line delete
    string_list = list(map(str.strip, string_list))  # Convert to list

    # 2.  space delete

    string_list = list(map(lambda x : x.replace(" "," "),string_list))

    # koita character

    number_of_character = list(map(lambda x : len(x),string_list))
    #total character
    total_number_of_characters = reduce(lambda x,y : x+y , number_of_character)

    print(total_number_of_characters)

# %%
from functools import reduce

with open("./sample_data/sample.txt", "r") as file:
    string_list = file.readlines()

    # total lines koyta
    total_lines = len(string_list)

    # word ber korbo
    number_of_words = list(map(lambda x: len(x.split()), string_list))

    print(number_of_words)
    total_number_of_words = reduce(lambda x, y: x + y, number_of_words)
    print(total_number_of_words)

    # 1. new line delete
    string_list = list(map(str.strip, string_list))

    # 2. space delete
    string_list = list(map(lambda x: x.replace(" ", ""), string_list))

    # koita character
    number_of_character = list(map(lambda x: len(x), string_list))

    # total character
    total_number_of_characters = reduce(lambda x, y: x + y, number_of_character)

    # Write to file
    with open("./sample_data/counter_of_string.txt", "w") as file:
        file.write(f"total line: {total_lines}\n total number of words: {total_number_of_words}\n total number of char: {total_number_of_characters}")

# %% [markdown]
# PRACTICE 2
#
# Wrie then read with one open

# %%
with open("./sample_data/write_read.txt","w+") as file:

  file.write("Hello World")

  print(file.tell())

  file.seek(0)
  print(file.tell())  ### Cursor problem

  print(file.read())

  file.truncate(5)

  file.seek(0)

  print(file.read())

# %% [markdown]
# EXCEPTION HANDLING

# %%
n = int(input())

try:
  a = 10/0
except  ZeroDivisionError :
  print("You cant devide a number by 0")


a = 10/0

print("Hello world")
# Out:
# 0
# You cant devide a number by 0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipython-input-2807958361.py in <cell line: 0>()
#       7
#       8
# ----> 9 a = 10/0
#      10
#      11 print("Hello world")
#
# ZeroDivisionError: division by zero

# %%
x = y

try:
  x=y
except ZeroDivisionError :
  print("you cant divide a number by 0")


print("hello world")


# Name Error
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1183747262.py in <cell line: 0>()
# ----> 1 x = y
#       2
#       3 try:
#       4   x=y
#       5 except ZeroDivisionError :
#
# NameError: name 'y' is not defined

# %%
x = y

try:
  x=y
except ZeroDivisionError :
  print("you cant divide a number by 0")
except NameError as ne:
  print(ne)

print("hello world")


# Output will be : Name Y is not defined  , hello world
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2868051820.py in <cell line: 0>()
# ----> 1 x = y
#       2
#       3 try:
#       4   x=y
#       5 except ZeroDivisionError :
#
# NameError: name 'y' is not defined

# %%
# Model Train

try:
  file = open(".sample_data/data1.txt","r")
  file.read()
except Exception as E :
  print(e)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-380414984.py in <cell line: 0>()
#       3 try:
# ----> 4   file = open(".sample_data/data1.txt","r")
#       5   file.read()
#
# FileNotFoundError: [Errno 2] No such file or directory: '.sample_data/data1.txt'
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-380414984.py in <cell line: 0>()
#       5   file.read()
#       6 except Exception as E :
# ----> 7   print(e)
#
# NameError: name 'e' is not defined
